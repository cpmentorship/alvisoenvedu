# %%
import pandas as pd

# %%
sat = pd.read_csv('https://raw.githubusercontent.com/data-8/materials-sp18/master/lec/sat2014.csv')
#don't worry about this line of code for now
sat.head(15) #see the first 15 entries
# Out:
#            State  Participation Rate  Critical Reading  Math  Writing  \
# 0   North Dakota                 2.3               612   620      584
# 1       Illinois                 4.6               599   616      587
# 2           Iowa                 3.1               605   611      578
# 3   South Dakota                 2.9               604   609      579
# 4      Minnesota                 5.9               598   610      578
# 5       Michigan                 3.8               593   610      581
# 6      Wisconsin                 3.9               596   608      578
# 7       Missouri                 4.2               595   597      579
# 8        Wyoming                 3.3               590   599      573
# 9         Kansas                 5.3               591   596      566
# 10      Kentucky                 4.6               589   585      572
# 11      Nebraska                 3.7               589   587      569
# ...

# %%
sat.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
x = sat.set_index("State").head(15)
x
# Out:
#               Participation Rate  Critical Reading  Math  Writing  Combined
# State
# North Dakota                 2.3               612   620      584      1816
# Illinois                     4.6               599   616      587      1802
# Iowa                         3.1               605   611      578      1794
# South Dakota                 2.9               604   609      579      1792
# Minnesota                    5.9               598   610      578      1786
# Michigan                     3.8               593   610      581      1784
# Wisconsin                    3.9               596   608      578      1782
# Missouri                     4.2               595   597      579      1771
# Wyoming                      3.3               590   599      573      1762
# Kansas                       5.3               591   596      566      1753
# Kentucky                     4.6               589   585      572      1746
# ...

# %%
x.reset_index()
# Out:
#            State  Participation Rate  Critical Reading  Math  Writing  \
# 0   North Dakota                 2.3               612   620      584
# 1       Illinois                 4.6               599   616      587
# 2           Iowa                 3.1               605   611      578
# 3   South Dakota                 2.9               604   609      579
# 4      Minnesota                 5.9               598   610      578
# 5       Michigan                 3.8               593   610      581
# 6      Wisconsin                 3.9               596   608      578
# 7       Missouri                 4.2               595   597      579
# 8        Wyoming                 3.3               590   599      573
# 9         Kansas                 5.3               591   596      566
# 10      Kentucky                 4.6               589   585      572
# 11      Nebraska                 3.7               589   587      569
# ...

# %%
sat.columns
# Out:
# Index(['State', 'Participation Rate', 'Critical Reading', 'Math', 'Writing',
#        'Combined'],
#       dtype='object')

# %%
sat.shape
# Out:
# (51, 6)

# %%
sat.head(3)
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 1      Illinois                 4.6               599   616      587      1802
# 2          Iowa                 3.1               605   611      578      1794

# %%
sat.tail(3)
# Out:
#                    State  Participation Rate  Critical Reading  Math  Writing  \
# 48                 Idaho               100.0               458   456      450
# 49              Delaware               100.0               456   459      444
# 50  District of Columbia               100.0               440   438      431
#
#     Combined
# 48      1364
# 49      1359
# 50      1309

# %%
sat.loc[[0, 3, 5, 7], ["State", "Math"]]
# Out:
#           State  Math
# 0  North Dakota   620
# 3  South Dakota   609
# 5      Michigan   610
# 7      Missouri   597

# %%
sat.loc[[0, 3, 5, 7], "State":"Writing"]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing
# 0  North Dakota                 2.3               612   620      584
# 3  South Dakota                 2.9               604   609      579
# 5      Michigan                 3.8               593   610      581
# 7      Missouri                 4.2               595   597      579

# %%
sat.loc[[0, 3, 5, 7], "State"]
# Out:
# 0    North Dakota
# 3    South Dakota
# 5        Michigan
# 7        Missouri
# Name: State, dtype: object

# %%
sat.loc[0, "State":"Writing"]
# Out:
# State                 North Dakota
# Participation Rate             2.3
# Critical Reading               612
# Math                           620
# Writing                        584
# Name: 0, dtype: object

# %%
sat.loc[10, "State"]
# Out:
# 'Kentucky'

# %%
sat.iloc[[0, 3, 5, 7], [0, 2, 5]]
# Out:
#           State  Critical Reading  Combined
# 0  North Dakota               612      1816
# 3  South Dakota               604      1792
# 5      Michigan               593      1784
# 7      Missouri               595      1771

# %%
sat.iloc[[0, 3, 5, 7], 0:5]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing
# 0  North Dakota                 2.3               612   620      584
# 3  South Dakota                 2.9               604   609      579
# 5      Michigan                 3.8               593   610      581
# 7      Missouri                 4.2               595   597      579

# %%
sat.iloc[0, [0, 1, 4]]
# Out:
# State                 North Dakota
# Participation Rate             2.3
# Writing                        584
# Name: 0, dtype: object

# %%
sat.iloc[10, 0]
# Out:
# 'Kentucky'

# %%
sat[4:17]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 4     Minnesota                 5.9               598   610      578      1786
# 5      Michigan                 3.8               593   610      581      1784
# 6     Wisconsin                 3.9               596   608      578      1782
# 7      Missouri                 4.2               595   597      579      1771
# 8       Wyoming                 3.3               590   599      573      1762
# 9        Kansas                 5.3               591   596      566      1753
# 10     Kentucky                 4.6               589   585      572      1746
# 11     Nebraska                 3.7               589   587      569      1745
# 12     Colorado                14.3               582   586      567      1735
# 13  Mississippi                 3.2               583   566      565      1714
# 14    Tennessee                 7.9               578   570      566      1714
# ...

# %%
sat[["State", "Math", "Combined"]]
# Out:
#                    State  Math  Combined
# 0           North Dakota   620      1816
# 1               Illinois   616      1802
# 2                   Iowa   611      1794
# 3           South Dakota   609      1792
# 4              Minnesota   610      1786
# 5               Michigan   610      1784
# 6              Wisconsin   608      1782
# 7               Missouri   597      1771
# 8                Wyoming   599      1762
# 9                 Kansas   596      1753
# 10              Kentucky   585      1746
# 11              Nebraska   587      1745
# 12              Colorado   586      1735
# 13           Mississippi   566      1714
# 14             Tennessee   570      1714
# 15              Arkansas   571      1698
# 16              Oklahoma   571      1697
# 17                  Utah   568      1690
# 18             Louisiana   556      1667
# 19                  Ohio   562      1652
# 20               Montana   552      1637
# 21               Alabama   538      1617
# ...

# %%
sat["State"]
# Out:
# 0             North Dakota
# 1                 Illinois
# 2                     Iowa
# 3             South Dakota
# 4                Minnesota
# 5                 Michigan
# 6                Wisconsin
# 7                 Missouri
# 8                  Wyoming
# 9                   Kansas
# 10                Kentucky
# 11                Nebraska
# 12                Colorado
# 13             Mississippi
# 14               Tennessee
# 15                Arkansas
# 16                Oklahoma
# 17                    Utah
# 18               Louisiana
# 19                    Ohio
# 20                 Montana
# 21                 Alabama
# 22              New Mexico
# 23           New Hampshire
# 24           Massachusetts
# 25                 Vermont
# 26                 Arizona
# 27                  Oregon
# 28                Virginia
# 29              New Jersey
# 30             Connecticut
# 31           West Virginia
# 32              Washington
# 33              California
# ...

# %% [markdown]
# ## Filtering Demo

# %%
x = sat.iloc[[0, 1, 2, 3], 0:5]
x
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing
# 0  North Dakota                 2.3               612   620      584
# 1      Illinois                 4.6               599   616      587
# 2          Iowa                 3.1               605   611      578
# 3  South Dakota                 2.9               604   609      579

# %%
x[[True, False, True, False]]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing
# 0  North Dakota                 2.3               612   620      584
# 2          Iowa                 3.1               605   611      578

# %%
top_10 = sat.head(10)
top_10
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 1      Illinois                 4.6               599   616      587      1802
# 2          Iowa                 3.1               605   611      578      1794
# 3  South Dakota                 2.9               604   609      579      1792
# 4     Minnesota                 5.9               598   610      578      1786
# 5      Michigan                 3.8               593   610      581      1784
# 6     Wisconsin                 3.9               596   608      578      1782
# 7      Missouri                 4.2               595   597      579      1771
# 8       Wyoming                 3.3               590   599      573      1762
# 9        Kansas                 5.3               591   596      566      1753

# %%
top_10[[True, False, True, False, True, False, True, False, True, False]]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 2          Iowa                 3.1               605   611      578      1794
# 4     Minnesota                 5.9               598   610      578      1786
# 6     Wisconsin                 3.9               596   608      578      1782
# 8       Wyoming                 3.3               590   599      573      1762

# %%
top_10["Math"] >= 610
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Math, dtype: bool

# %%
top_10[top_10["Math"] >= 610]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 1      Illinois                 4.6               599   616      587      1802
# 2          Iowa                 3.1               605   611      578      1794
# 4     Minnesota                 5.9               598   610      578      1786
# 5      Michigan                 3.8               593   610      581      1784

# %%
(top_10["Math"] >= 610) & (top_10["Writing"] >= 579)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
top_10[(top_10["Math"] >= 610) & (top_10["Writing"] >= 579)]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 1      Illinois                 4.6               599   616      587      1802
# 5      Michigan                 3.8               593   610      581      1784

# %%
top_10[(top_10["Math"] >= 610) | (top_10["Writing"] >= 579)]
# Out:
#           State  Participation Rate  Critical Reading  Math  Writing  Combined
# 0  North Dakota                 2.3               612   620      584      1816
# 1      Illinois                 4.6               599   616      587      1802
# 2          Iowa                 3.1               605   611      578      1794
# 3  South Dakota                 2.9               604   609      579      1792
# 4     Minnesota                 5.9               598   610      578      1786
# 5      Michigan                 3.8               593   610      581      1784
# 7      Missouri                 4.2               595   597      579      1771
